# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r'/home/kathan/Downloads/city_day.csv')

# %%
df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
df.tail()
# Out:
#                 City        Date  PM2.5   PM10    NO    NO2    NOx    NH3  \
# 29526  Visakhapatnam  2020-06-27  15.02  50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97  4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00  0.40  26.85  14.05   5.20
#
#          CO    SO2     O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 29526  0.47   8.55  23.30     2.24    12.07    0.73  41.0          Good
# 29527  0.52  12.72  30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528  0.48   8.42  30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529  0.52   9.84  28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530  0.59   2.10  17.05      NaN      NaN     NaN  50.0          Good

# %%
df.shape
# Out:
# (29531, 16)

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %% [markdown]
# # Commit Required Changes In Datatypes

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  datetime64[ns]
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 3.6+ MB

# %%
# extract date, month, and year into separate columns
df['date'] = df['Date'].dt.day
df['month'] = df['Date'].dt.month
df['year'] = df['Date'].dt.year

# %%
df.drop(['Date'],axis=1,inplace=True)

# %%
df.drop(['AQI_Bucket'],axis=1,inplace=True)

# %%
df.head()
# Out:
#         City  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2      O3  \
# 0  Ahmedabad    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64  133.36
# 1  Ahmedabad    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55   34.06
# 2  Ahmedabad    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07   30.70
# 3  Ahmedabad    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59   36.08
# 4  Ahmedabad    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33   39.31
#
#    Benzene  Toluene  Xylene  AQI  date  month  year
# 0     0.00     0.02    0.00  NaN     1      1  2015
# 1     3.68     5.50    3.77  NaN     2      1  2015
# 2     6.80    16.40    2.25  NaN     3      1  2015
# 3     4.43    10.14    1.00  NaN     4      1  2015
# 4     7.01    18.89    2.78  NaN     5      1  2015

# %%
df.select_dtypes(exclude='number')
# Out:
#                 City
# 0          Ahmedabad
# 1          Ahmedabad
# 2          Ahmedabad
# 3          Ahmedabad
# 4          Ahmedabad
# ...              ...
# 29526  Visakhapatnam
# 29527  Visakhapatnam
# 29528  Visakhapatnam
# 29529  Visakhapatnam
# 29530  Visakhapatnam
#
# [29531 rows x 1 columns]

# %%
df.City.unique()
# Out:
# array(['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru',
#        'Bhopal', 'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore',
#        'Delhi', 'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad',
#        'Jaipur', 'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai',
#        'Patna', 'Shillong', 'Talcher', 'Thiruvananthapuram',
#        'Visakhapatnam'], dtype=object)

# %%
df.City.value_counts()
# Out:
# Ahmedabad             2009
# Delhi                 2009
# Mumbai                2009
# Bengaluru             2009
# Lucknow               2009
# Chennai               2009
# Hyderabad             2006
# Patna                 1858
# Gurugram              1679
# Visakhapatnam         1462
# Amritsar              1221
# Jorapokhar            1169
# Jaipur                1114
# Thiruvananthapuram    1112
# Amaravati              951
# Brajrajnagar           938
# Talcher                925
# Kolkata                814
# Guwahati               502
# Coimbatore             386
# Shillong               310
# Chandigarh             304
# Bhopal                 289
# Ernakulam              162
# Kochi                  162
# Aizawl                 113
# Name: City, dtype: int64

# %% [markdown]
# # Identify Numerical and Categorical Features

# %%
num = df.select_dtypes(include="number").columns 
print(num)
# Out:
# Index(['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'Xylene', 'AQI', 'date', 'month', 'year'],
#       dtype='object')

# %%
cat = df.select_dtypes(exclude="number").columns
print(cat)
# Out:
# Index(['City'], dtype='object')

# %% [markdown]
# # Visualize null / Missing Values

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Get the percentages of null value

# %%
df.shape
# Out:
# (29531, 17)

# %%
null_percent = df.isnull().sum()/df.shape[0]*100
null_percent
# Out:
# City        0.000000
# PM2.5      15.570079
# PM10       37.723071
# NO         12.129626
# NO2        12.139785
# NOx        14.171549
# NH3        34.973418
# CO          6.972334
# SO2        13.050692
# O3         13.619586
# Benzene    19.041008
# Toluene    27.229014
# Xylene     61.322001
# AQI        15.851139
# date        0.000000
# month       0.000000
# year        0.000000
# dtype: float64

# %%
# Another method to find percentage

null_percent_2 = df.isnull().mean()*100
null_percent_2
# Out:
# City        0.000000
# PM2.5      15.570079
# PM10       37.723071
# NO         12.129626
# NO2        12.139785
# NOx        14.171549
# NH3        34.973418
# CO          6.972334
# SO2        13.050692
# O3         13.619586
# Benzene    19.041008
# Toluene    27.229014
# Xylene     61.322001
# AQI        15.851139
# date        0.000000
# month       0.000000
# year        0.000000
# dtype: float64

# %%
col_for_drop = null_percent[null_percent > 40].keys() # if the null value % 20 or > 20 so need to drop it

# %%
col_for_drop
# Out:
# Index(['Xylene'], dtype='object')

# %%
sns.heatmap(df[col_for_drop].isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Dropping Column Xylene Due to 60% OF Missing Value

# %%
df.drop(['Xylene'],axis=1,inplace=True)

# %%
df_new = df.copy()

# %%
# Filled NaN values in 11 columns in Df
columns_to_fill_nan = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene']
df_new[columns_to_fill_nan] = df_new[columns_to_fill_nan].fillna(df_new[columns_to_fill_nan].median(numeric_only=False))

# %%
df.isnull().sum()
# Out:
# City           0
# PM2.5       4598
# PM10       11140
# NO          3582
# NO2         3585
# NOx         4185
# NH3        10328
# CO          2059
# SO2         3854
# O3          4022
# Benzene     5623
# Toluene     8041
# AQI         4681
# date           0
# month          0
# year           0
# dtype: int64

# %%
df_new.isnull().sum()
# Out:
# City          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# AQI        4681
# date          0
# month         0
# year          0
# dtype: int64

# %% [markdown]
# # Function to see box and histplot

# %%
def boxhistplot(df,figsize=(16,5)):
    plt.figure(figsize=figsize)
    plt.subplot(121)
    sns.boxplot(df)
    plt.subplot(122)
    sns.distplot(df,kde=True)

# %%
boxhistplot(df["PM2.5"])

# %% [markdown]
# # Function To Comapare Old And New Distribution

# %%
def old_new_boxhistplot(df,df_new,feature,figsize=(16,10)):
    plt.figure(figsize=figsize)
    plt.subplot(221)
    sns.boxplot(df[feature])
    plt.title("Old Data")
    plt.subplot(222)
    sns.distplot(df[feature])
    plt.title("Old Data")
    
    plt.subplot(223)
    sns.boxplot(df_new[feature])
    plt.title("New Data")
    plt.subplot(224)
    sns.distplot(df_new[feature])
    plt.title("New Data")

# %%
old_new_boxhistplot(df,df_new,"PM2.5")

# %% [markdown]
# ## Find the Plots for all the columns

# %%
features = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
       'Benzene', 'Toluene'] # list of features to plot

for feat in features:
    old_new_boxhistplot(df, df_new, feat)
    plt.show() # show the plot after each iteration

# %% [markdown]
# # Handling With Outliers

# %%
features
# Out:
# ['PM2.5',
#  'PM10',
#  'NO',
#  'NO2',
#  'NOx',
#  'NH3',
#  'CO',
#  'SO2',
#  'O3',
#  'Benzene',
#  'Toluene']

# %% [markdown]
# ## If The Data Is Normally Distributed We use this

# %%
##### Assuming Age follows A Gaussian Distribution we will calculate the boundaries which differentiates the outliers

uppper_boundary=df_new['CO'].mean() + 3* df_new['CO'].std()
lower_boundary=df_new['CO'].mean() - 3* df_new['CO'].std()
print(lower_boundary), print(uppper_boundary),print(df_new['CO'].mean())
# Out:
# -18.02010914955962
# 22.327853553744983
# 2.1538722020926806
# (None, None, None)

# %% [markdown]
# ## If Features Are Skewed We Use the below Technique

# %%
df_new['CO'].describe()
# Out:
# count    29531.000000
# mean         2.153872
# std          6.724660
# min          0.000000
# 25%          0.540000
# 50%          0.890000
# 75%          1.380000
# max        175.810000
# Name: CO, dtype: float64

# %%
figure=df_new.CO.hist(bins=100)
figure.set_title('Fare')
figure.set_xlabel('Fare')
figure.set_ylabel('No of passenger')
# Out:
# Text(0, 0.5, 'No of passenger')

# %%
#### Lets compute the Interquantile range to calculate the boundaries
IQR=df_new['CO'].quantile(0.75)-df['CO'].quantile(0.25)

# %%
IQR
# Out:
# 0.8699999999999999

# %%
lower_bridge=df_new['CO'].quantile(0.25)-(IQR*1.5)
upper_bridge=df_new['CO'].quantile(0.75)+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# -0.7649999999999997
# 2.6849999999999996
# (None, None)

# %%
#### Extreme outliers
lower_bridge=df_new['CO'].quantile(0.25)-(IQR*3)
upper_bridge=df_new['CO'].quantile(0.75)+(IQR*3)
print(lower_bridge), print(upper_bridge)
# Out:
# -2.0699999999999994
# 3.9899999999999993
# (None, None)

# %%
df_new.loc[df_new['CO']>=4,'CO']=4

# %%
figure=df_new.CO.hist(bins=100)
figure.set_title('Fare')
figure.set_xlabel('Fare')
figure.set_ylabel('No of passenger')
# Out:
# Text(0, 0.5, 'No of passenger')

# %%
df_new['Benzene'].describe()
# Out:
# count    29531.000000
# mean         2.859874
# std         14.252822
# min          0.000000
# 25%          0.240000
# 50%          1.070000
# 75%          2.420000
# max        455.030000
# Name: Benzene, dtype: float64

# %%
features = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene'] # list of features to process

for feat in features:
    IQR = df_new[feat].quantile(0.75) - df_new[feat].quantile(0.25)
    lower_bridge = df_new[feat].quantile(0.25) - (IQR * 3)
    upper_bridge = df_new[feat].quantile(0.75) + (IQR * 3)
    df_new.loc[df_new[feat] >= upper_bridge, feat] = upper_bridge

# %% [markdown]
# # We can Create a FUNCTION To Replace OutliersValue

# %%
def remove_outliers(df, features):
    
    for feat in features:
        IQR = df[feat].quantile(0.75) - df[feat].quantile(0.25)
        lower_bridge = df[feat].quantile(0.25) - (IQR * 3)
        upper_bridge = df[feat].quantile(0.75) + (IQR * 3)
        df.loc[df[feat] >= upper_bridge, feat] = upper_bridge
        
    return df

# %%
features
# Out:
# ['PM2.5',
#  'PM10',
#  'NO',
#  'NO2',
#  'NOx',
#  'NH3',
#  'CO',
#  'SO2',
#  'O3',
#  'Benzene',
#  'Toluene']

# %%
features = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene']
df_new = remove_outliers(df_new, features)

# %%
df_new.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  29531.000000  29531.000000  29531.000000  29531.000000  29531.000000
# mean      61.076147    102.065051     14.670097     27.186764     29.635190
# std       44.709175     47.305400     13.424440     20.392056     23.720501
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       32.150000     79.315000      6.210000     12.980000     14.670000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       72.450000    111.880000     17.570000     34.665000     36.015000
# max      193.350000    209.575000     51.650000     99.720000    100.050000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  29531.000000  29531.000000  29531.000000  29531.000000  29531.000000
# mean      18.938206      1.140610     11.969407     33.855791      1.884088
# ...

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
df.CO.size
# Out:
# 29531

# %%
df_new.CO.size
# Out:
# 29531

# %% [markdown]
# This function will delete the outliers but previous function set the upper value in the outliers.
#
# def treat_outliers(df, feature):
#     IQR = df[feature].quantile(0.75) - df[feature].quantile(0.25)
#     lower_bridge = df[feature].quantile(0.25) - (IQR*3)
#     upper_bridge = df[feature].quantile(0.75) + (IQR*3)
#     df = df.loc[(df[feature] >= lower_bridge) & (df[feature] <= upper_bridge)]
#     return df

# %%
df_new
# Out:
#                 City  PM2.5   PM10     NO    NO2    NOx    NH3    CO    SO2  \
# 0          Ahmedabad  48.57  95.68   0.92  18.22  17.15  15.85  0.92  27.64
# 1          Ahmedabad  48.57  95.68   0.97  15.69  16.46  15.85  0.97  24.55
# 2          Ahmedabad  48.57  95.68  17.40  19.30  29.70  15.85  3.90  29.07
# 3          Ahmedabad  48.57  95.68   1.70  18.48  17.97  15.85  1.70  18.59
# 4          Ahmedabad  48.57  95.68  22.10  21.42  37.76  15.85  3.90  36.97
# ...              ...    ...    ...    ...    ...    ...    ...   ...    ...
# 29526  Visakhapatnam  15.02  50.94   7.68  25.06  19.54  12.47  0.47   8.55
# 29527  Visakhapatnam  24.38  74.09   3.42  26.06  16.53  11.99  0.52  12.72
# 29528  Visakhapatnam  22.91  65.73   3.45  29.53  18.33  10.71  0.48   8.42
# 29529  Visakhapatnam  16.64  49.97   4.05  29.26  18.80  10.03  0.52   9.84
# 29530  Visakhapatnam  15.00  66.00   0.40  26.85  14.05   5.20  0.59   2.10
#
#            O3  Benzene  Toluene   AQI  date  month  year
# ...

# %% [markdown]
# # AQI Outliers and Missing Value Imputation

# %%
df_new.isnull().sum()
# Out:
# City          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# AQI        4681
# date          0
# month         0
# year          0
# dtype: int64

# %%
df_new['AQI'] = df_new['AQI'].fillna(df_new['AQI'].median(numeric_only=False))

# %%
df_new.isnull().sum().sum()
# Out:
# 0

# %%
features = ['AQI']

df_new = remove_outliers(df_new,features)

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
df_new.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  29531.000000  29531.000000  29531.000000  29531.000000  29531.000000
# mean      61.076147    102.065051     14.670097     27.186764     29.635190
# std       44.709175     47.305400     13.424440     20.392056     23.720501
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       32.150000     79.315000      6.210000     12.980000     14.670000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       72.450000    111.880000     17.570000     34.665000     36.015000
# max      193.350000    209.575000     51.650000     99.720000    100.050000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  29531.000000  29531.000000  29531.000000  29531.000000  29531.000000
# mean      18.938206      1.140610     11.969407     33.855791      1.884088
# ...

# %% [markdown]
# # Categorical Value Encoding

# %%
cat
# Out:
# Index(['City'], dtype='object')

# %%
vc = df_new.City.value_counts()

# %%
index = vc.index

# %%
index
# Out:
# Index(['Ahmedabad', 'Delhi', 'Mumbai', 'Bengaluru', 'Lucknow', 'Chennai',
#        'Hyderabad', 'Patna', 'Gurugram', 'Visakhapatnam', 'Amritsar',
#        'Jorapokhar', 'Jaipur', 'Thiruvananthapuram', 'Amaravati',
#        'Brajrajnagar', 'Talcher', 'Kolkata', 'Guwahati', 'Coimbatore',
#        'Shillong', 'Chandigarh', 'Bhopal', 'Ernakulam', 'Kochi', 'Aizawl'],
#       dtype='object')

# %% [markdown]
# # Ordinal Encoding

# %%
df_new.columns
# Out:
# Index(['City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'AQI', 'date', 'month', 'year'],
#       dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
# Create a list of cities
cities = ['Ahmedabad', 'Delhi', 'Mumbai', 'Bengaluru', 'Lucknow', 'Chennai', 'Hyderabad', 
          'Patna', 'Gurugram', 'Visakhapatnam', 'Amritsar', 'Jorapokhar', 'Jaipur', 
          'Thiruvananthapuram', 'Amaravati', 'Brajrajnagar', 'Talcher', 'Kolkata', 
          'Guwahati', 'Coimbatore', 'Shillong', 'Chandigarh', 'Bhopal', 'Ernakulam', 
          'Kochi', 'Aizawl']

# %%
encoder = OrdinalEncoder()

# %%
df_new['City_encoded'] = encoder.fit_transform(df_new[['City']])+1

# %%
df_new
# Out:
#                 City  PM2.5   PM10     NO    NO2    NOx    NH3    CO    SO2  \
# 0          Ahmedabad  48.57  95.68   0.92  18.22  17.15  15.85  0.92  27.64
# 1          Ahmedabad  48.57  95.68   0.97  15.69  16.46  15.85  0.97  24.55
# 2          Ahmedabad  48.57  95.68  17.40  19.30  29.70  15.85  3.90  29.07
# 3          Ahmedabad  48.57  95.68   1.70  18.48  17.97  15.85  1.70  18.59
# 4          Ahmedabad  48.57  95.68  22.10  21.42  37.76  15.85  3.90  36.97
# ...              ...    ...    ...    ...    ...    ...    ...   ...    ...
# 29526  Visakhapatnam  15.02  50.94   7.68  25.06  19.54  12.47  0.47   8.55
# 29527  Visakhapatnam  24.38  74.09   3.42  26.06  16.53  11.99  0.52  12.72
# 29528  Visakhapatnam  22.91  65.73   3.45  29.53  18.33  10.71  0.48   8.42
# 29529  Visakhapatnam  16.64  49.97   4.05  29.26  18.80  10.03  0.52   9.84
# 29530  Visakhapatnam  15.00  66.00   0.40  26.85  14.05   5.20  0.59   2.10
#
# ...

# %%
df_new['City_encoded'] = df_new['City_encoded'].astype(int)

# %%
df_new
# Out:
#                 City  PM2.5   PM10     NO    NO2    NOx    NH3    CO    SO2  \
# 0          Ahmedabad  48.57  95.68   0.92  18.22  17.15  15.85  0.92  27.64
# 1          Ahmedabad  48.57  95.68   0.97  15.69  16.46  15.85  0.97  24.55
# 2          Ahmedabad  48.57  95.68  17.40  19.30  29.70  15.85  3.90  29.07
# 3          Ahmedabad  48.57  95.68   1.70  18.48  17.97  15.85  1.70  18.59
# 4          Ahmedabad  48.57  95.68  22.10  21.42  37.76  15.85  3.90  36.97
# ...              ...    ...    ...    ...    ...    ...    ...   ...    ...
# 29526  Visakhapatnam  15.02  50.94   7.68  25.06  19.54  12.47  0.47   8.55
# 29527  Visakhapatnam  24.38  74.09   3.42  26.06  16.53  11.99  0.52  12.72
# 29528  Visakhapatnam  22.91  65.73   3.45  29.53  18.33  10.71  0.48   8.42
# 29529  Visakhapatnam  16.64  49.97   4.05  29.26  18.80  10.03  0.52   9.84
# 29530  Visakhapatnam  15.00  66.00   0.40  26.85  14.05   5.20  0.59   2.10
#
# ...

# %%
df_new.City.nunique()
# Out:
# 26

# %%
df_new.City_encoded.nunique()
# Out:
# 26

# %%
import pandas as pd


# group the data by city code and get a list of cities for each code
city_codes = df_new.groupby('City_encoded')['City'].unique()

# print the city codes and their corresponding cities
for code, cities in city_codes.items():
    print(f'City code {code} belongs to {", ".join(cities)}')
# Out:
# City code 1 belongs to Ahmedabad
# City code 2 belongs to Aizawl
# City code 3 belongs to Amaravati
# City code 4 belongs to Amritsar
# City code 5 belongs to Bengaluru
# City code 6 belongs to Bhopal
# City code 7 belongs to Brajrajnagar
# City code 8 belongs to Chandigarh
# City code 9 belongs to Chennai
# City code 10 belongs to Coimbatore
# City code 11 belongs to Delhi
# City code 12 belongs to Ernakulam
# City code 13 belongs to Gurugram
# City code 14 belongs to Guwahati
# City code 15 belongs to Hyderabad
# City code 16 belongs to Jaipur
# City code 17 belongs to Jorapokhar
# City code 18 belongs to Kochi
# City code 19 belongs to Kolkata
# City code 20 belongs to Lucknow
# City code 21 belongs to Mumbai
# City code 22 belongs to Patna
# City code 23 belongs to Shillong
# City code 24 belongs to Talcher
# City code 25 belongs to Thiruvananthapuram
# City code 26 belongs to Visakhapatnam

# %%
import pandas as pd

city_codes = {
    1: 'Ahmedabad',
    2: 'Aizawl',
    3: 'Amaravati',
    4: 'Amritsar',
    5: 'Bengaluru',
    6: 'Bhopal',
    7: 'Brajrajnagar',
    8: 'Chandigarh',
    9: 'Chennai',
    10: 'Coimbatore',
    11: 'Delhi',
    12: 'Ernakulam',
    13: 'Gurugram',
    14: 'Guwahati',
    15: 'Hyderabad',
    16: 'Jaipur',
    17: 'Jorapokhar',
    18: 'Kochi',
    19: 'Kolkata',
    20: 'Lucknow',
    21: 'Mumbai',
    22: 'Patna',
    23: 'Shillong',
    24: 'Talcher',
    25: 'Thiruvananthapuram',
    26: 'Visakhapatnam'
}

city_codes_df = pd.DataFrame(city_codes.items(), columns=['City Code', 'City'])

# %%
city_codes_df
# Out:
#     City Code                City
# 0           1           Ahmedabad
# 1           2              Aizawl
# 2           3           Amaravati
# 3           4            Amritsar
# 4           5           Bengaluru
# 5           6              Bhopal
# 6           7        Brajrajnagar
# 7           8          Chandigarh
# 8           9             Chennai
# 9          10          Coimbatore
# 10         11               Delhi
# 11         12           Ernakulam
# 12         13            Gurugram
# 13         14            Guwahati
# 14         15           Hyderabad
# 15         16              Jaipur
# 16         17          Jorapokhar
# 17         18               Kochi
# 18         19             Kolkata
# 19         20             Lucknow
# 20         21              Mumbai
# 21         22               Patna
# 22         23            Shillong
# 23         24             Talcher
# 24         25  Thiruvananthapuram
# 25         26       Visakhapatnam

# %%
city_codes_df.to_csv('city_codes.csv', index=False)

# %%
#df_new.to_csv("city_.csv",index=False)

# %%
df_new.drop(['City'],axis=1,inplace=True)

# %%
df_new
# Out:
#                 City  PM2.5   PM10     NO    NO2    NOx    NH3    CO    SO2  \
# 0          Ahmedabad  48.57  95.68   0.92  18.22  17.15  15.85  0.92  27.64
# 1          Ahmedabad  48.57  95.68   0.97  15.69  16.46  15.85  0.97  24.55
# 2          Ahmedabad  48.57  95.68  17.40  19.30  29.70  15.85  3.90  29.07
# 3          Ahmedabad  48.57  95.68   1.70  18.48  17.97  15.85  1.70  18.59
# 4          Ahmedabad  48.57  95.68  22.10  21.42  37.76  15.85  3.90  36.97
# ...              ...    ...    ...    ...    ...    ...    ...   ...    ...
# 29526  Visakhapatnam  15.02  50.94   7.68  25.06  19.54  12.47  0.47   8.55
# 29527  Visakhapatnam  24.38  74.09   3.42  26.06  16.53  11.99  0.52  12.72
# 29528  Visakhapatnam  22.91  65.73   3.45  29.53  18.33  10.71  0.48   8.42
# 29529  Visakhapatnam  16.64  49.97   4.05  29.26  18.80  10.03  0.52   9.84
# 29530  Visakhapatnam  15.00  66.00   0.40  26.85  14.05   5.20  0.59   2.10
#
# ...

# %%
#df_new.to_csv("FinalAQI.csv",index=False)

# %%
#df_new.to_csv("outliers.csv",index=False)

# %% [markdown]
# import pandas as pd
#
#
# # merge columns into a string
# df['date_month_year'] = df.apply(lambda x: '{}/{}/{}'.format(x['date'], x['month'], x['year']), axis=1)
#
# print(df)

# %% [markdown]
# # convert columns to date format
# df['date'] = pd.to_datetime(df['date'], format='%d')
# df['month'] = pd.to_datetime(df['month'], format='%m')
# df['year'] = pd.to_datetime(df['year'], format='%Y')
#
# # merge the columns into a single column
# df['date'] = df['year'].dt.strftime('%Y-%m-%d')
#
# # drop the original year, month, and day columns
# df = df.drop(columns=['year', 'month'])

# %%
df_new.to_csv('EDA_mod.csv',index=False)

# %%
df_new.columns
# Out:
# Index(['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'AQI', 'date', 'month', 'year', 'City_encoded'],
#       dtype='object')
